# %%
import os

# %%
import pandas as pd

# %%
data = pd.read_csv("..\\House_Price_Data\\HousePrice.csv")

# %%
data.shape
# Out:
# (545, 13)

# %%
df= data.sample(50)

# %%
df.columns
# Out:
# Index(['price', 'area', 'bedrooms', 'bathrooms', 'stories', 'mainroad',
#        'guestroom', 'basement', 'hotwaterheating', 'airconditioning',
#        'parking', 'prefarea', 'furnishingstatus'],
#       dtype='object')

# %%
df=df.drop(["price"],axis=1)

# %%
df.to_csv("HousePrice.csv",index=False)

# %%
df.head()
# Out:
#      area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 516  3240         2          1        1       no       yes       no
# 202  4120         2          1        1      yes        no      yes
# 519  4840         2          1        2      yes        no       no
# 33   5960         3          3        2      yes       yes      yes
# 294  4000         4          2        2       no        no       no
#
#     hotwaterheating airconditioning  parking prefarea furnishingstatus
# 516              no              no        1       no      unfurnished
# 202              no              no        1       no   semi-furnished
# 519              no              no        0       no      unfurnished
# 33               no              no        1       no      unfurnished
# 294              no              no        0       no   semi-furnished

# %%
df.values
# Out:
# array([[3240, 2, 1, 1, 'no', 'yes', 'no', 'no', 'no', 1, 'no',
#         'unfurnished'],
#        [4120, 2, 1, 1, 'yes', 'no', 'yes', 'no', 'no', 1, 'no',
#         'semi-furnished'],
#        [4840, 2, 1, 2, 'yes', 'no', 'no', 'no', 'no', 0, 'no',
#         'unfurnished'],
#        [5960, 3, 3, 2, 'yes', 'yes', 'yes', 'no', 'no', 1, 'no',
#         'unfurnished'],
#        [4000, 4, 2, 2, 'no', 'no', 'no', 'no', 'no', 0, 'no',
#         'semi-furnished'],
#        [3180, 2, 2, 1, 'yes', 'no', 'yes', 'no', 'no', 2, 'no',
#         'semi-furnished'],
#        [8580, 4, 3, 4, 'yes', 'no', 'no', 'no', 'yes', 2, 'yes',
#         'semi-furnished'],
#        [3060, 3, 1, 1, 'yes', 'no', 'no', 'no', 'no', 0, 'no',
#         'unfurnished'],
#        [6862, 3, 1, 2, 'yes', 'no', 'no', 'no', 'yes', 2, 'yes',
#         'furnished'],
#        [3360, 2, 1, 1, 'yes', 'no', 'no', 'no', 'no', 1, 'no',
#         'unfurnished'],
#        [7231, 3, 1, 2, 'yes', 'yes', 'yes', 'no', 'yes', 0, 'yes',
# ...

# %%
data.columns
# Out:
# Index(['price', 'area', 'bedrooms', 'bathrooms', 'stories', 'mainroad',
#        'guestroom', 'basement', 'hotwaterheating', 'airconditioning',
#        'parking', 'prefarea', 'furnishingstatus'],
#       dtype='object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 545 entries, 0 to 544
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   price             545 non-null    int64
#  1   area              545 non-null    int64
#  2   bedrooms          545 non-null    int64
#  3   bathrooms         545 non-null    int64
#  4   stories           545 non-null    int64
#  5   mainroad          545 non-null    object
#  6   guestroom         545 non-null    object
#  7   basement          545 non-null    object
#  8   hotwaterheating   545 non-null    object
#  9   airconditioning   545 non-null    object
#  10  parking           545 non-null    int64
#  11  prefarea          545 non-null    object
#  12  furnishingstatus  545 non-null    object
# dtypes: int64(6), object(7)
# memory usage: 55.5+ KB

# %%
data.describe()
# Out:
#               price          area    bedrooms   bathrooms     stories  \
# count  5.450000e+02    545.000000  545.000000  545.000000  545.000000
# mean   4.766729e+06   5150.541284    2.965138    1.286239    1.805505
# std    1.870440e+06   2170.141023    0.738064    0.502470    0.867492
# min    1.750000e+06   1650.000000    1.000000    1.000000    1.000000
# 25%    3.430000e+06   3600.000000    2.000000    1.000000    1.000000
# 50%    4.340000e+06   4600.000000    3.000000    1.000000    2.000000
# 75%    5.740000e+06   6360.000000    3.000000    2.000000    2.000000
# max    1.330000e+07  16200.000000    6.000000    4.000000    4.000000
#
#           parking
# count  545.000000
# mean     0.693578
# std      0.861586
# min      0.000000
# 25%      0.000000
# 50%      0.000000
# 75%      1.000000
# max      3.000000

# %%
data.isnull().sum()
# Out:
# price               0
# area                0
# bedrooms            0
# bathrooms           0
# stories             0
# mainroad            0
# guestroom           0
# basement            0
# hotwaterheating     0
# airconditioning     0
# parking             0
# prefarea            0
# furnishingstatus    0
# dtype: int64

# %%
data.isnull().sum().sum()
# Out:
# np.int64(0)

# %%
data.isna().sum().sum()
# Out:
# np.int64(0)

# %%
#pip install seaborn

# %%
import matplotlib.pyplot as plot
import seaborn as sns

# %%
plot.figure(figsize=(15,50), facecolor='white')
plotnumber =1

for column in data.drop(['price'],axis=1):
    ax = plot.subplot(12,3,plotnumber)
    sns.violinplot(data= data,x=data[column],y =data["price"] )
    plot.xlabel(column,fontsize=10)
    plotnumber+=1
plot.show()

# %%
data
# Out:
#         price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0    13300000  7420         4          2        3      yes        no       no
# 1    12250000  8960         4          4        4      yes        no       no
# 2    12250000  9960         3          2        2      yes        no      yes
# 3    12215000  7500         4          2        2      yes        no      yes
# 4    11410000  7420         4          1        2      yes       yes      yes
# ..        ...   ...       ...        ...      ...      ...       ...      ...
# 540   1820000  3000         2          1        1      yes        no      yes
# 541   1767150  2400         3          1        1       no        no       no
# 542   1750000  3620         2          1        1      yes        no       no
# 543   1750000  2910         3          1        1       no        no       no
# 544   1750000  3850         3          1        2      yes        no       no
#
# ...

# %%
print("Skewness:", data['price'].skew())
print("Kurtosis:", data['price'].kurt())
# Out:
# Skewness: 1.2122388370279802
# Kurtosis: 1.9601302314151994

# %%
import numpy as np
data['log_price'] = np.log1p(data['price'])

# Visualize the transformed distribution
sns.histplot(data['log_price'], kde=True)
plt.title("Log-Transformed Price Distribution")
plt.xlabel("log(price + 1)")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[22], line 6
#       4 # Visualize the transformed distribution
#       5 sns.histplot(data['log_price'], kde=True)
# ----> 6 plt.title("Log-Transformed Price Distribution")
#       7 plt.xlabel("log(price + 1)")
#       8 plt.show()
#
# NameError: name 'plt' is not defined

# %%
data.columns
# Out:
# Index(['price', 'area', 'bedrooms', 'bathrooms', 'stories', 'mainroad',
#        'guestroom', 'basement', 'hotwaterheating', 'airconditioning',
#        'parking', 'prefarea', 'furnishingstatus', 'log_price'],
#       dtype='object')

# %%
numerical_df = data.select_dtypes(include=['number'])

# %%
print(numerical_df)
# Out:
#         price  area  bedrooms  bathrooms  stories  parking  log_price
# 0    13300000  7420         4          2        3        2  16.403275
# 1    12250000  8960         4          4        4        3  16.321037
# 2    12250000  9960         3          2        2        2  16.321037
# 3    12215000  7500         4          2        2        3  16.318175
# 4    11410000  7420         4          1        2        2  16.250001
# ..        ...   ...       ...        ...      ...      ...        ...
# 540   1820000  3000         2          1        1        2  14.414348
# 541   1767150  2400         3          1        1        0  14.384879
# 542   1750000  3620         2          1        1        0  14.375127
# 543   1750000  2910         3          1        1        0  14.375127
# 544   1750000  3850         3          1        2        0  14.375127
#
# [545 rows x 7 columns]

# %%
categorical_df = data.select_dtypes(include=['object', 'category'])

# %%
print(categorical_df)
# Out:
#     mainroad guestroom basement hotwaterheating airconditioning prefarea  \
# 0        yes        no       no              no             yes      yes
# 1        yes        no       no              no             yes       no
# 2        yes        no      yes              no              no      yes
# 3        yes        no      yes              no             yes      yes
# 4        yes       yes      yes              no             yes       no
# ..       ...       ...      ...             ...             ...      ...
# 540      yes        no      yes              no              no       no
# 541       no        no       no              no              no       no
# 542      yes        no       no              no              no       no
# 543       no        no       no              no              no       no
# 544      yes        no       no              no              no       no
#
#     furnishingstatus
# 0          furnished
# 1          furnished
# 2     semi-furnished
# ...

# %%
# Get list of numerical column names
numerical_columns = df.select_dtypes(include='number').columns.tolist()

# Get list of categorical column names (object and category)
categorical_columns = df.select_dtypes(include=['object', 'category']).columns.tolist()

# %%
print(numerical_columns)
# Out:
# ['area', 'bedrooms', 'bathrooms', 'stories', 'parking']

# %%
print(categorical_columns)
# Out:
# ['mainroad', 'guestroom', 'basement', 'hotwaterheating', 'airconditioning', 'prefarea', 'furnishingstatus']
